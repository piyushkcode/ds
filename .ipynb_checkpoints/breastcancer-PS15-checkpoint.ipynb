# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'E:\DSBDAL\DSBDALExam DataSets\DSBDALExam DataSets\BreastCancer\breast-cancer.csv')

# Display first few rows
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
print(df.columns)
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
# Step 1: Data Cleaning
# Check missing values
df.columns = ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
print("Missing Values:\n", df.isnull().sum())

# Check "?" entries
print("Question Mark Entries:\n", (df == '?').sum())

# Check negative values
numeric_cols = ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
# Convert columns to numeric (invalid parsing will be set as NaN)
for col in numeric_cols:
    if col != 'diagnosis':  # skip non-numeric column
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Now safely check for negative values
print("Negative Values:\n", (df[numeric_cols].select_dtypes(include='number') < 0).sum())
# Out:
# Missing Values:
#  id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64
# Question Mark Entries:
#  id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64
# Negative Values:
#  id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# Step 2: Error Correction (Remove outliers using IQR)
# Ensure numeric_cols only has numeric dtypes
numeric_cols = df.select_dtypes(include='number').columns

def remove_outliers(data, column):
    # Drop rows where this column has NaN
    col_data = data[column].dropna()
    Q1 = col_data.quantile(0.25)
    Q3 = col_data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

for col in numeric_cols:
    df = remove_outliers(df, col)

print("\nShape after outlier removal:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8     return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
#      10 for col in numeric_cols:
# ---> 11     df = remove_outliers(df, col)
#      13 print("\nShape after outlier removal:", df.shape)
#
# Cell In[7], line 3, in remove_outliers(data, column)
#       2 def remove_outliers(data, column):
# ----> 3     Q1 = data[column].quantile(0.25)
#       4     Q3 = data[column].quantile(0.75)
#       5     IQR = Q3 - Q1
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:2887, in Series.quantile(self, q, interpolation)
#    2883 # We dispatch to DataFrame so that core.internals only has to worry
#    2884 #  about 2D cases.
#    2885 df = self.to_frame()
# -> 2887 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888 if result.ndim == 2:
#    2889     result = result.iloc[:, 0]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:12146, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12140 axis = self._get_axis_number(axis)
#   12142 if not is_list_like(q):
#   12143     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12144     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146     res_df = self.quantile(
#   12147         [q],  # type: ignore[list-item]
#   12148         axis=axis,
#   12149         numeric_only=numeric_only,
#   12150         interpolation=interpolation,
#   12151         method=method,
#   12152     )
#   12153     if method == "single":
#   12154         res = res_df.iloc[0]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:12191, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12187     raise ValueError(
#   12188         f"Invalid method: {method}. Method must be in {valid_method}."
#   12189     )
#   12190 if method == "single":
# > 12191     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12192 elif method == "table":
#   12193     valid_interpolation = {"nearest", "lower", "higher"}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:1549, in BlockManager.quantile(self, qs, interpolation)
#    1545 new_axes = list(self.axes)
#    1546 new_axes[1] = Index(qs, dtype=np.float64)
#    1548 blocks = [
# -> 1549     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1550 ]
#    1552 return type(self)(blocks, new_axes)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\blocks.py:1891, in Block.quantile(self, qs, interpolation)
#    1888 assert self.ndim == 2
#    1889 assert is_list_like(qs)  # caller is responsible for this
# -> 1891 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1892 # ensure_block_shape needed for cases where we start with EA and result
#    1893 #  is ndarray, e.g. IntegerArray, SparseArray
#    1894 result = ensure_block_shape(result, ndim=2)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\array_algos\quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\array_algos\quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\array_algos\quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:4238, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4235     if np.any(weights < 0):
#    4236         raise ValueError("Weights must be non-negative.")
# -> 4238 return _quantile_unchecked(
#    4239     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:4517, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4508 def _quantile_unchecked(a,
#    4509                         q,
#    4510                         axis=None,
#    (...)
#    4514                         keepdims=False,
#    4515                         weights=None):
#    4516     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4517     return _ureduce(a,
#    4518                     func=_quantile_ureduce_func,
#    4519                     q=q,
#    4520                     weights=weights,
#    4521                     keepdims=keepdims,
#    4522                     axis=axis,
#    4523                     out=out,
#    4524                     overwrite_input=overwrite_input,
#    4525                     method=method)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:3848, in _ureduce(a, func, keepdims, **kwargs)
#    3845             index_out = (0, ) * nd
#    3846             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3848 r = func(a, **kwargs)
#    3850 if out is not None:
#    3851     return out
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:4694, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4692         arr = a.copy()
#    4693         wgt = weights
# -> 4694 result = _quantile(arr,
#    4695                    quantiles=q,
#    4696                    axis=axis,
#    4697                    method=method,
#    4698                    out=out,
#    4699                    weights=wgt)
#    4700 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:4826, in _quantile(arr, quantiles, axis, method, out, weights)
#    4824         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4825         gamma = gamma.reshape(result_shape)
# -> 4826         result = _lerp(previous,
#    4827                     next,
#    4828                     gamma,
#    4829                     out=out)
#    4830 else:
#    4831     # Weighted case
#    4832     # This implements method="inverted_cdf", the only supported weighted
#    4833     # method, which needs to sort anyway.
#    4834     weights = np.asanyarray(weights)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_function_base_impl.py:4620, in _lerp(a, b, t, out)
#    4606 def _lerp(a, b, t, out=None):
#    4607     """
#    4608     Compute the linear interpolation weighted by gamma on each point of
#    4609     two same shape array.
#    (...)
#    4618         Output array.
#    4619     """
# -> 4620     diff_b_a = subtract(b, a)
#    4621     # asanyarray is a stop-gap until gh-13105
#    4622     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
